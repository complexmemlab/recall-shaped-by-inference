# %% [markdown]
# ## Data cleaning notebook
#
# This notebook will allow you to run the processing code for the data presented in the paper. If you run the cells in this notebook it will overwrite the data in the interim and processed folders. Feel free to change where the data paths are pointing or redownload the repo if you want to leave the final data alone.
#
# The code to regenerate the data is in `src.data.clean_raw_data` which will produce the data in the interim folder. Then the modeling code is run by `src.models.fit_rl` which will produce the csv that has the model fits in the processed folder. Finally the code in `src.models.gen_rpe` is used to make the final csv that has the RPEs required for some of the analyses in the paper.
#
# An example of the reinforcement learning model fit for a given participant and set of parameters is given in 02-model-fitting.ipynb notebook. The model takes about 10 minutes to run for all the participants, so to save time we have included the model fits in the processed folder.
#
# The following code filters out participants based on the the criteria we describe in the text:
# - Participants who did not complete the task (non-response on 20% or more of trials)
# - Participants who did not recall at least one word per run

# %%
# !python -m src.data.clean_raw_data \
-i ../../data/raw/wordsconsinfr.csv \
-o ../..//data/interim/
# Out:
# /Users/abkara/grad_school/wordsconsin-studies/papers/recall-shaped-by-inference/src/data/clean_raw_data.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   math_trials["eq"] = math_trials.stimulus.apply(lambda x: x[5:-1])
# /Users/abkara/grad_school/wordsconsin-studies/papers/recall-shaped-by-inference/src/data/clean_raw_data.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   math_trials["correct_math_ans"] = math_trials["eq"].apply(
# ...

# %% [markdown]
# Then once the model fits have been run we can add the RPEs using the `src.models.gen_rpe` module. This will produce the final data that is used in the paper.

# %%
# !python -m src.models.gen_rpe \
-f ../../data/processed/DecayFeatureRL_no_resp_st_results.csv \
-s ../../data/interim/strat_df.csv \
-o ../../data/processed/
# Out:
# /Users/abkara/grad_school/wordsconsin-studies/papers/recall-shaped-by-inference/src/models/gen_rpe.py:22: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(input_path)
# /Users/abkara/grad_school/wordsconsin-studies/papers/recall-shaped-by-inference/src/models/gen_rpe.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_strat_data["rpe"] = rpe
# /Users/abkara/grad_school/wordsconsin-studies/papers/recall-shaped-by-inference/src/models/gen_rpe.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# Now the data are ready to use in the other notebooks!
